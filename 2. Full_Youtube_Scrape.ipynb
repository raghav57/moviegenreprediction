# %%
# reading data
import pandas as pd
movieId = pd.read_csv(r'D:\Machine Learning\Vamsi Thesis\Data\ml-25m\links.csv')
movieId.info()
youtubeId = pd.read_csv(r'D:\Machine Learning\Vamsi Thesis\Data\ml-20m-youtube\ml-youtube.csv')
youtubeId.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62423 entries, 0 to 62422
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   movieId  62423 non-null  int64
#  1   imdbId   62423 non-null  int64
#  2   tmdbId   62316 non-null  float64
# dtypes: float64(1), int64(2)
# memory usage: 1.4 MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25623 entries, 0 to 25622
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   youtubeId  25623 non-null  object
#  1   movieId    25623 non-null  int64
#  2   title      25623 non-null  object
# dtypes: int64(1), object(2)
# memory usage: 600.7+ KB

# %%
def youtubeExtract(id):
    from youtube_transcript_api import YouTubeTranscriptApi
    try:
        transcript = YouTubeTranscriptApi.get_transcript(id, languages)
        trailerTranscript = ' '.join([transcript[i]['text'] for i in range(len(transcript))])
        return trailerTranscript
    except:
        return ''

# %%
# scraping full trailer transcripts from youtube
import time
import json

# starting time
start = time.time()
from youtubesearchpython import SearchVideos

movieNames = youtubeId['title'].tolist()


def youtubeTranscripts(movieName):
    print(movieName)
    search = SearchVideos(movieName + 'trailer', offset = 1, mode = "json", max_results = 20)

    test = search.result()

    res = json.loads(test)
    temp = list(res.values())
    idList= [temp[0][i]['id'] for i in range(len(temp[0]))]
    tv = list(enumerate(idList))
    
    transcripts=[]
    # c=0
    try:
        for c, val in enumerate(idList):
            transcripts.append(youtubeExtract(val))
            finalTrans = transcripts[c]
            if transcripts[c]!='':
                break;
        return finalTrans
    except:
        return ''

# check = youtubeId.head()

# check['trailerTranscript'] = check.apply(lambda row:youtubeTranscripts(row['title']),axis=1)

# print(check)

youtubeId.to_pickle(r"D:\Machine Learning\Vamsi Thesis\Code\trailerTranscripts.pkl")
# total time taken
youtubeId['trailerTranscript'] = youtubeId.apply(lambda row:youtubeTranscripts(row['title']),axis=1)
youtubeId.to_pickle(r"D:\Machine Learning\Vamsi Thesis\Code\trailerTranscripts.pkl")
end = time.time()
print(f"Runtime of the program is {int((end - start)/3600)} hours")
# Out:
# Toy Story (1995)
# Jumanji (1995)
# Grumpier Old Men (1995)
# Waiting to Exhale (1995)
# Father of the Bride Part II (1995)
# Heat (1995)
# Sabrina (1995)
# Tom and Huck (1995)
# Sudden Death (1995)
# GoldenEye (1995)
# American President, The (1995)
# Dracula: Dead and Loving It (1995)
# Balto (1995)
# Nixon (1995)
# Cutthroat Island (1995)
# Casino (1995)
# Sense and Sensibility (1995)
# Four Rooms (1995)
# Ace Ventura: When Nature Calls (1995)
# Money Train (1995)
# Get Shorty (1995)
# Copycat (1995)
# Assassins (1995)
# Powder (1995)
# Leaving Las Vegas (1995)
# Othello (1995)
# Now and Then (1995)
# Persuasion (1995)
# City of Lost Children, The (Cité des enfants perdus, La) (1995)
# Shanghai Triad (Yao a yao yao dao waipo qiao) (1995)
# Dangerous Minds (1995)
# Twelve Monkeys (a.k.a. 12 Monkeys) (1995)
# Wings of Courage (1995)
# Babe (1995)
# Carrington (1995)
# Dead Man Walking (1995)
# Across the Sea of Time (1995)
# It Takes Two (1995)
# Clueless (1995)
# ...

# %%
check = youtubeId[youtubeId['trailerTranscript']=='']
check.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2511 entries, 79 to 25622
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   youtubeId          2511 non-null   object
#  1   movieId            2511 non-null   int64
#  2   title              2511 non-null   object
#  3   trailerTranscript  2511 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 98.1+ KB

# %%
youtubeId.head()
# Out:
#      youtubeId  movieId                               title  \
# 0  K26_sDKnvMU        1                    Toy Story (1995)
# 1  3LPANjHlPxo        2                      Jumanji (1995)
# 2  rEnOoWs3FuA        3             Grumpier Old Men (1995)
# 3  j9xml1CxgXI        4            Waiting to Exhale (1995)
# 4  ltwvKLnj1B4        5  Father of the Bride Part II (1995)
#
#                                    trailerTranscript
# 0  sergeant yes sir establish a recon post downst...
# 1  It's gotta be micro-chipped or something You g...
# 2  or on hot crankier my dog was as ugly as you l...
# 3  [Music] savannah bernadine robin gloria [Music...
# 4  [Music] we're George banks life was good it wa...

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\ragha
